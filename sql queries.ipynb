# %% [markdown]
# ## The Look “Shipping and Stock Performance Review on Q1 - Q2 2023
# By : Gentur Herlambang

# %% [markdown]
# # Introduction
# Welcome to the notebook that focuses on the shipping and stock performance review of "The Look," an e-commerce company, for the first and second quarters of 2023 (Q1-Q2 2023). This analysis aims to provide insights into various aspects of the company's operations, including order status, top shipped categories, distribution center performance, top destination countries, and cancelation status based on gender. By answering these questions, we will gain a comprehensive understanding of the company's performance during this period.
#
# # Questions to be Answered:
#
# 1.Order Status: We will examine the distribution of order status for Q1-Q2 2023. This analysis will provide insights into the overall efficiency of order processing and identify any potential issues or bottlenecks.
#
# 2.Top Shipped Categories: We will identify the top categories of products that were shipped during the specified period. This information will help us understand the customers' preferences and the company's most popular product lines.
#
# 3.Distribution Center Performance: We will assess the performance of each distribution center in terms of order fulfillment and shipping. This analysis will help identify any disparities in performance and determine areas for improvement.
#
# 4.Top Destination Countries: We will determine the top destination countries to which The Look shipped its products during Q1-Q2 2023. This analysis will provide insights into the company's international reach and potential growth opportunities in specific regions.
#
# 5.Cancelation Status based on Gender: We will examine the cancelation status of orders based on gender. By analyzing this data, we can determine if there is any correlation between gender and order cancelation, which may help in understanding customer behavior patterns.
#
#
#
# By the end of this analysis, we aim to provide actionable insights and recommendations to optimize The Look's shipping and stock performance, improve customer satisfaction, and drive business growth.

# %% [markdown]
# # Methodology
# To answer these questions, we will utilize the dataset from "The Look" e-commerce company, focusing on the relevant tables such as orders, products, distribution centers, and user demographics. We will leverage SQL queries and data manipulation techniques to extract the required information and generate meaningful insights. Additionally, visualizations will be employed to present the findings in a clear and concise manner.

# %% [markdown]
# # 1.Order Status
# Order status is a crucial metric for evaluating the efficiency of order processing and overall operational performance of an e-commerce company. In this analysis, we will examine the distribution of order statuses for Q1-Q2 2023. The order statuses typically include categories such as "Shipped," "Completed," "Cancelled," and "Returned."
#
# By studying the distribution of order statuses, we can gain insights into the effectiveness and efficiency of the order fulfillment process. We will be able to identify any potential issues or bottlenecks that may have occurred during this period.
#
# The queries that i use are :
#
#  SELECT o.status, COUNT(*) AS order_count
#
#  FROM `bigquery-public-data.thelook_ecommerce.orders` o
#
#  LEFT JOIN `bigquery-public-data.thelook_ecommerce.order_items` oi ON o.order_id = oi.order_id
#
#  LEFT JOIN `bigquery-public-data.thelook_ecommerce.products` p ON oi.product_id = p.id
#
#  WHERE o.created_at >= TIMESTAMP("2023-01-01") AND o.created_at <= TIMESTAMP("2023-06-30")
#
#  GROUP BY o.status
#
#
#  ORDER BY order_count DESC;

# %% [markdown]
# ![order status.png](<attachment:order status.png>)

# %% [markdown]
# In our analysis of the shipping and stock performance of The Look during Q1-Q2 2023, we have observed that the completed shipment rate is approximately 25%. This means that around 25% of the orders placed during this period were successfully shipped to customers. On the other hand, the combined percentage of returned and canceled orders is also estimated to be around 25%. This indicates that a significant portion of the orders did not reach their intended destination or were canceled by the customers.
#
# To put these figures into perspective, we can refer to industry standards and benchmarks. According to industry data provided by CleverTap (source: https://clevertap.com/blog/ecommerce-return-rate-statistics/), the average return rate in the e-commerce industry is around 30%. This means that, on average, 30% of the orders placed by customers in the industry are returned or canceled.
#
# Comparing our findings to the industry benchmark, we can conclude that The Look is currently performing better than the average in terms of return and cancellation rates. Our combined return and cancellation rate of 25% is below the industry standard of 30%. This indicates that The Look has been successful in maintaining a relatively lower rate of order returns and cancellations compared to the industry average.

# %% [markdown]
# # 2.Top Shipped Categories
# Understanding customers' preferences and the popularity of product categories is crucial for the success of an e-commerce company. In this analysis, we will identify the top categories of products that were shipped during the specified period (Q1-Q2 2023). By determining the most shipped product categories, we can gain valuable insights into customers' preferences, the company's most popular product lines, and potential market trends.
#
# the queries that i use are :
#
# SELECT p.category, COUNT(*) as order_count
#
# FROM `bigquery-public-data.thelook_ecommerce.orders` o
#
# LEFT JOIN `bigquery-public-data.thelook_ecommerce.order_items` oi ON o.order_id = oi.order_id
#
# LEFT JOIN `bigquery-public-data.thelook_ecommerce.products` p ON oi.product_id = p.id
#
# WHERE o.created_at >= TIMESTAMP("2023-01-01") AND o.created_at <= TIMESTAMP("2023-06-30")
#
# GROUP BY p.category
#
# ORDER BY order_count DESC;

# %% [markdown]
# ![categories.jpg](attachment:categories.jpg)

# %% [markdown]
# During the first half of 2023, The Look, an e-commerce platform, shipped a variety of products to its customers. Our analysis reveals that the top three categories of items that were shipped during this period are Intimate, Jeans, and Tops and Tees. These categories have consistently shown higher shipping volumes compared to other product categories. This information is valuable for understanding customer preferences and can guide inventory planning and marketing strategies.
#
# However, it is worth noting that the gap between the top 10 categories does not show significant differences in terms of shipping volumes. While Intimate, Jeans, and Tops and Tees stand out as the top three categories, the remaining categories within the top 10 do not exhibit substantial variations in shipping quantities.
#
# This finding suggests that The Look's customers have diverse preferences across different product categories, and there isn't a significant concentration of shipping volume on a single category beyond the top three. This diversified customer demand across multiple categories is a positive aspect as it indicates a broad customer base and a range of products that appeal to different segments of the market.

# %% [markdown]
# # 3.Distribution Center Performance
# Distribution centers play a crucial role in an e-commerce company's operations, as they are responsible for order fulfillment and shipping. In this analysis, we will assess the performance of each distribution center in terms of order fulfillment and shipping. By evaluating their performance, we can identify any disparities and determine areas that require improvement.
#
# the queries that i use are :
#
# SELECT ii.product_distribution_center_id, COUNT(*) AS product_count
#
# FROM `bigquery-public-data.thelook_ecommerce.inventory_items` ii
#
# JOIN `bigquery-public-data.thelook_ecommerce.order_items` oi ON ii.product_id = oi.product_id
#
# JOIN `bigquery-public-data.thelook_ecommerce.orders` o ON oi.order_id = o.order_id
#
# WHERE o.status IN ('Shipped', 'Completed')
#
#   AND EXTRACT(YEAR FROM o.created_at) = 2023
#
#   AND EXTRACT(QUARTER FROM o.created_at) <= 2
#
# GROUP BY ii.product_distribution_center_id
#
# ORDER BY product_count DESC;

# %% [markdown]
# ![distribution center.jpg](<attachment:distribution center.jpg>)

# %% [markdown]
# In our analysis of the shipping and stock performance of The Look during Q1-Q2 2023, we have identified the top three distribution centers that played a significant role in sending out products to customers. These distribution centers, labeled as Center 1, Center 2, and Center 3, have collectively shipped approximately 45 thousand items during the specified period.
#
# The shipping volume of these top three distribution centers is notably higher compared to the other centers, which have shipped around 30 thousand items on average. This indicates a significant difference in performance and highlights the effectiveness and efficiency of Center 1, Center 2, and Center 3 in fulfilling and delivering customer orders.

# %% [markdown]
# # 4.Top Destination Countries
# Understanding the top destination countries to which The Look shipped its products during Q1-Q2 2023 is essential for assessing the company's international reach and identifying potential growth opportunities. By analyzing the shipment data and identifying the countries with the highest order volumes, this analysis will provide valuable insights into the company's global performance and highlight regions where The Look has established a strong presence.
#
# the queries that i use are :
#
#
#
# WITH
#   cust AS (
#
#     SELECT
#
#       DISTINCT oi.user_id,
#
#       u.country AS country
#
#     FROM `bigquery-public-data.thelook_ecommerce.order_items` AS oi
#
#     INNER JOIN `bigquery-public-data.thelook_ecommerce.users` AS u
#
#     ON oi.user_id = u.id
#
#     WHERE oi.status NOT IN ('Cancelled','Returned')
#
#       AND EXTRACT(YEAR FROM oi.created_at) = 2023
#
#       AND EXTRACT(QUARTER FROM oi.created_at) <= 2
#
#     GROUP BY 1, 2
#
#   )
#
#
# SELECT
#
#   c.country,
#
#
#   COUNT(DISTINCT c.user_id) AS customers_count
#
# FROM cust AS c
#
# GROUP BY 1
#
# ORDER BY 2 DESC
#
# LIMIT 5;

# %% [markdown]
# ![Global costumer.jpg](<attachment:Global costumer.jpg>)

# %% [markdown]
# During our analysis of the shipping and stock performance of The Look in Q1-Q2 2023, we have identified the top destination countries to which our products were shipped. It is noteworthy that a significant number of orders were delivered to countries outside our domestic market. Among these countries, China and Korea stand out as the highest recipients of our products.
#
# China, being our largest market in terms of order volume, holds immense potential for future global expansion. The substantial number of orders shipped to China indicates a high demand for our products in this market. Expanding our operations in China can not only help us tap into the existing customer base but also enable us to explore new growth opportunities. By establishing a stronger presence in China, we can further solidify our position and cater to the increasing demand for our products.
#
# In addition to China, Korea also emerges as a significant market for The Look. Despite being a smaller market compared to China, Korea's presence in our top 5 destination countries indicates a consistent demand for our products. This suggests that there is a loyal customer base in Korea who appreciates and values our offerings. By strategically targeting the Korean market, we can leverage this existing customer base and further expand our reach in the region.
#
# Expanding into these top destination countries, particularly China and Korea, aligns with our growth strategy to tap into new markets and diversify our customer base. These countries have demonstrated a strong interest in our products, which indicates a favorable market environment for The Look. By tailoring our marketing and distribution strategies to cater to the preferences and needs of customers in these markets, we can effectively capture a larger market share and drive revenue growth.

# %% [markdown]
# # 5.Cancelation Status based on Gender:
# Understanding the cancelation status of orders based on gender can provide valuable insights into customer behavior and potential factors that influence order cancelations. By analyzing the data and examining if there is any correlation between gender and order cancelation, we can uncover patterns and trends that may help The Look make informed decisions to optimize their operations and customer experience.
#
# the queries that i sue are :
#
# SELECT gender, COUNT(*) AS canceled_count
#
# FROM `bigquery-public-data.thelook_ecommerce.orders`
#
# WHERE status = 'Cancelled'
#
# GROUP BY gender;

# %% [markdown]
# ![gender.jpg](attachment:gender.jpg)

# %% [markdown]
# During our analysis of order cancelation based on gender, we have observed that there is a difference in the cancelation percentages between male and female customers. This finding suggests that gender may play a role in influencing the decision to cancel an order.
#
# It is interesting to note that both male and female customers exhibit a similar pattern in terms of cancelation rates. This implies that factors beyond gender, such as product dissatisfaction, delivery issues, or changes in personal circumstances, may have a more significant impact on the cancelation decision.

# %% [markdown]
# # Conclusion
# In conclusion, the analysis of The Look's shipping and stock performance for Q1-Q2 of 2023 has provided valuable insights into various aspects of the business. Here are the key takeaways from our findings:
#
# -Order Status Distribution: The distribution of order statuses indicates that approximately 25% of orders were completed, while the combined percentage of returned and canceled orders is also around 25%. Although there is room for improvement, The Look's performance is below the industry standard of 30% return rate, as reported in industry statistics.
#
# -Top Shipped Categories: The top three categories of items shipped during the first half of 2023 are Intimates, Jeans, and Tops and Tees. While these categories show a higher volume of shipments, the gap between the top 10 categories is not significantly different. This suggests that The Look's customers have diverse preferences across a range of product categories.
#
# -Distribution Center Performance: The analysis reveals that Distribution Centers 1, 2, and 3 stand out as the top performers, shipping around 45,000 items during Q1-Q2 of 2023, while other centers shipped around 30,000 items. This highlights the need for further examination of the operational efficiency and processes across all distribution centers to ensure consistent performance.
#
# -Destination Countries: The analysis indicates that a significant number of orders are shipped to countries outside the home market, with China and Korea emerging as the top destinations. These findings present an opportunity for The Look to consider expanding further into the Chinese market and leveraging its strong presence in Korea to tap into additional growth opportunities.
#
# -Gender-based Order Cancelation: The analysis suggests that there is no significant difference between male and female customers in terms of order cancelation percentages. This finding indicates that cancelation decisions are influenced by factors beyond gender, such as product satisfaction, delivery issues, or personal circumstances. It emphasizes the importance of considering a holistic approach when addressing order cancelations and tailoring strategies to meet the specific needs and concerns of all customers.
#
# By leveraging these insights, The Look can make data-driven decisions and take targeted actions to optimize its shipping and stock performance, improve customer satisfaction, and drive business growth. Addressing bottlenecks in order processing, optimizing inventory planning based on popular categories, enhancing distribution center performance, expanding into key international markets, and tailoring marketing strategies to customer preferences will contribute to the overall success and competitiveness of The Look in the e-commerce industry.
